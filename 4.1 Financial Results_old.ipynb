# %% [markdown]
# # Integration of SVM and MVO
#
# This notebook computes and visualizes the results of the computational experiments

# %%
import numpy as np
from pandas.tseries.offsets import Day, MonthBegin
pth = 'cache/Experiments/'
local_path = 'cache/Local Experiments/'
cache_path = 'cache/'
img_path = "Images/"

from python.packages import *
from python.analysis_tools import *
import pickle
# %matplotlib inline
dpi_setting = 150

# %%
## Import Monthly Returns
rets = pd.read_pickle(cache_path + "RETS.pkl")
## Import feature vectors
wrds_svm = pd.read_pickle(cache_path + "WRDS_ASOF.pkl")
## Import Daily Prices
Prices = pd.read_pickle(cache_path + "Daily_Prices.pkl")
## Get the trade dates
StockDates = wrds_svm.reset_index().loc[:, ['Date', 'MonthStart', 'MonthEnd']].drop_duplicates()

#risk free rate data
FF_RiskFree = pd.read_csv(cache_path + "F-F_Research_Data_Factors.CSV")
FF_RiskFree.Date = pd.to_datetime(FF_RiskFree['Date'], format='%Y%m', errors='coerce')
FF_RiskFree.index = FF_RiskFree.Date
FF_RiskFree.drop(FF_RiskFree.columns[0:4], axis=1, inplace = True)

# %%
daily_rets = Prices.pct_change() + 1
new_index = daily_rets.index[0:-1] #VERY IMPORTANT
daily_rets.drop(daily_rets.head(1).index,inplace=True)
daily_rets.index = new_index
Prices['StartMonth'] = Prices.index + Day(1) + MonthBegin(-1)
#this calculate the month of the stock returns
daily_rets['StartMonth'] = daily_rets.index + Day(1) + MonthBegin(-1)
# daily_rets[['AAPL', 'StartMonth']].head()
# daily_rets.dropna(inplace = True)
# daily_rets.head()

# %%
# daily_portfolio = pd.merge(weights_mvo, daily_rets.reset_index()[['Date', 'StartMonth']], how='left', left_index = True, right_on = 'StartMonth')
# daily_portfolio.index = daily_portfolio.Date
#Rets.index.isin(StockDates.MonthStart.values)
(daily_rets).groupby('StartMonth').prod().iloc[8:].head() - 1
# Out:
#                 AAPL       ABC      ABMD       ABT      ADBE       ADI  \
# StartMonth
# 2000-07-01 -0.075030  0.149590  0.194030 -0.043729 -0.105083 -0.184231
# 2000-08-01  0.286440 -0.007130  0.565625  0.025185  0.182414  0.552152
# 2000-09-01 -0.617734  0.412926  0.045908  0.108381  0.204822 -0.171393
# 2000-10-01 -0.154641 -0.102922 -0.125954  0.107287 -0.052148 -0.291667
# 2000-11-01 -0.167680  0.107649 -0.192140  0.000000 -0.128641 -0.119748
#
#                  ADM       ADP      ADSK       AEE  ...       WMB       WMT  \
# StartMonth                                          ...
# 2000-07-01 -0.018750 -0.034648 -0.424388  0.071684  ...  0.040179 -0.041758
# 2000-08-01 -0.058899  0.194307  0.386707  0.076923  ...  0.086912 -0.105505
# 2000-09-01  0.042857  0.076122 -0.128540  0.072135  ... -0.088809 -0.050227
# 2000-10-01  0.219178 -0.000965 -0.157850 -0.044117  ... -0.005797  0.009461
# 2000-11-01  0.151331  0.002896  0.285714  0.096923  ... -0.185131  0.096384
#
#                   WY       XEL      XLNX       XOM      XRAY       XRX  \
# StartMonth
# 2000-07-01  0.080448  0.132415 -0.166544  0.005695  0.142562 -0.245399
# 2000-08-01 -0.053455  0.119107  0.294014  0.036879  0.014466  0.069129
# 2000-09-01 -0.165289  0.100985 -0.051700  0.108334 -0.003583 -0.057692
# 2000-10-01  0.193338 -0.050657 -0.225969  0.006835 -0.001792 -0.440816
# 2000-11-01  0.013947  0.023752 -0.406858 -0.030599  0.086176 -0.264868
#
#                  YUM      ZBRA
# StartMonth
# 2000-07-01 -0.098253  0.158960
# 2000-08-01  0.157385  0.062344
# 2000-09-01  0.031381 -0.167840
# 2000-10-01 -0.016227 -0.055007
# 2000-11-01  0.129897  0.007463
#
# [5 rows x 286 columns]

# %%
from itertools import product
turnovers = ["0_75", "1", "1_25"]
cardinalities  = ["Card01", "Card03", "Card05", "Card07", "Card09"]
card_strings = [r"$K = \lfloor 0.1N \rfloor$", r"$K = \lfloor0.3N\rfloor$", r"$K = \lfloor0.5N \rfloor$", r"$K = \lfloor0.7N \rfloor$", r"$K = \lfloor0.9N \rfloor$"]
turnover_strings = ["$C_0 = 0.75/6$", "$C_0 = 1.00/6$", "$C_0 = 1.25/6$"]

epsilon = 1e-3 #change epsilon to generate different tables

epsilons_desc = {1e-2:"eps negative 2", 1e-3:"eps negative 3",
                 1e-4:"eps negative 4", 1e-5:"eps negative 5"}

oot_returns_card_mvo_dict = {}
oot_returns_mvo_dict = {}
oot_returns_svm_dict = {}
oot_returns_adm_fundamentals_dict = {}
oot_returns_adm_vol_dict = {}
T = len(rets.index)

cols_fundamentals = "_INV3PRO6INV1_"
name_fundamentals = "final_reg"

cols_vol = "_INV3PRO6INV1_"
name_vol = "final_lightreg"

cols_vol = "_Vol_"
name_vol = "balanced"

for (turnover, card) in product(turnovers, cardinalities):

    with open(local_path + "Cardinality Portfolios/"+card+"_"+turnover+"no_tlim.pkl",'rb') as fp:
        card_mvo_results = pickle.load(fp)
    with open(local_path + "Standard MVO Portfolios/"+turnover+"no_tlim.pkl",'rb') as fp:
        mvo_results = pickle.load(fp)
    # with open(pth + "svm_oot_results_turnover0_75by6.pkl", 'rb') as fp:
    #   svm_results = pickle.load(fp)
    with open(local_path + epsilons_desc[epsilon] + "/" + card + "_Vol_" +turnover + "no_tlim.pkl", 'rb') as fp:
        svm_results = pickle.load(fp)
    with open(local_path + epsilons_desc[epsilon] + "/" + "padm" +card+ cols_fundamentals +turnover + name_fundamentals + ".pkl", 'rb') as fp:
        adm_fundamentals_results = pickle.load(fp)
    with open(local_path + epsilons_desc[epsilon] + "/" + "padm" +card+ cols_vol +turnover + name_vol + ".pkl", 'rb') as fp:
        adm_vol_results = pickle.load(fp)
#     with open(local_path + epsilons_desc[epsilon] + "/" + "padm" +card+ "_VolINV3_" +turnover + "no_neg.pkl", 'rb') as fp:
#         adm_results2 = pickle.load(fp)
    weights_card_mvo, oot_returns_card_mvo, market_card_mvo, wis_card_mvo, bias_card_mvo, soln_mods_card_mvo = card_mvo_results
    weights_mvo, oot_returns_mvo, market_mvo, wis_mvo, bias_mvo, soln_mods_mvo = mvo_results
    weights_svm, oot_returns_svm, market_svm, wis_svm, bias_svm, soln_mods_svm = svm_results
    weights_adm_fundamentals, oot_returns_adm_fundamentals, market_adm_fundamentals, \
    wis_adm_fundamentals, bias_adm_fundamentals, soln_mods_adm_fundamentals, times = adm_fundamentals_results

    weights_adm_vol, oot_returns_adm_vol, market_adm_vol, \
    wis_adm_vol, bias_adm_vol, soln_mods_adm_vol, times = adm_vol_results

    # weights_adm2, oot_returns_adm2, market_adm2, wis_adm2, bias_adm2, soln_mods_adm2, times2 = adm_results2
    oot_returns_card_mvo_dict[(card, turnover)] = (weights_card_mvo.iloc[:-1]*rets).sum(axis = 1)
    oot_returns_mvo_dict[(card, turnover)] = (weights_mvo.iloc[:-1]*rets).sum(axis = 1)
    oot_returns_svm_dict[(card, turnover)] = (weights_svm.iloc[:-1]*rets).sum(axis = 1)
    oot_returns_adm_fundamentals_dict[(card, turnover)] = (weights_adm_fundamentals.iloc[:-1]*rets).sum(axis = 1)
    oot_returns_adm_vol_dict[(card, turnover)] = (weights_adm_vol.iloc[:-1]*rets).sum(axis = 1)
    # oot_returns_adm_dict2[(card, turnover)] = (weights_adm2.iloc[:-1]*rets).sum(axis = 1)
rf = FF_RiskFree[FF_RiskFree.index.isin(oot_returns_adm_fundamentals.index)]
rf = rf.RF;

# %%
plt.plot(wis_svm)

# %%
max_y = 0
min_y = 0.8
lw = 1
fig, axs = plt.subplots(len(cardinalities), len(turnovers),
                        sharex=True, sharey = True, figsize=(6.5,8.5))
for (i ,j) in product(range(len(cardinalities)), range(len(turnovers))):
    turnover = turnovers[j]
    card = cardinalities[i]
    svm_wealth = wealth(oot_returns_svm_dict[(card, turnover)])
    mvo_wealth = wealth(oot_returns_mvo_dict[(card, turnover)])
    card_mvo_wealth = wealth(oot_returns_card_mvo_dict[(card, turnover)])
    adm_fundamentals_wealth = wealth(oot_returns_adm_fundamentals_dict[(card, turnover)])
    adm_vol_wealth = wealth(oot_returns_adm_vol_dict[(card, turnover)])
    T = len(adm_fundamentals_wealth)
    #(svm_wealth/mvo_wealth).plot(label = 'Exact Solve - Vol', fontsize = 8, ax=axs[i, j], linewidth = lw)
    #(adm_fundamentals_wealth/mvo_wealth).plot(label = 'PADM - Fundamentals', fontsize = 8, ax=axs[i, j], linewidth = lw)
    (adm_vol_wealth/mvo_wealth).plot(label = 'PADM - Vol', fontsize = 8, ax=axs[i, j], linewidth = lw)
    (card_mvo_wealth/mvo_wealth).plot(label = 'Card-MVO', fontsize = 8, ax=axs[i, j], linewidth = lw)
    card_string = card_strings[i]
    turnover_string = turnover_strings[j]
    axs[i, j].set_title(card_string + ", " + turnover_string, fontsize = 8)
    max_ = max(np.max((adm_fundamentals_wealth/mvo_wealth)), np.max((adm_fundamentals_wealth/mvo_wealth)))
    if max_ > max_y:
        max_y = max_
axs[4, 1].legend(loc='upper center',
             bbox_to_anchor=(0.3, -0.5),
                 fancybox=False,
                 shadow=False, ncol=3,
                 fontsize = 8)

for ax in axs:
    for sub_ax in ax:
        sub_ax.yaxis.set_tick_params(which='minor', bottom=False)
        sub_ax.set_yticks([min_y+i*0.2 for i in range(2+int((max_y - min_y)/0.2))])
        sub_ax.grid()
        sub_ax.set_xlabel("Trade Date",fontsize = 8)
# fig.supxlabel('Trade Date',fontsize = 8)
fig.supylabel("Cumulative Relative Wealth",fontsize = 8)
#plt.tight_layout()
fig.subplots_adjust(wspace = 0.05, hspace=0.4)
#plt.setp(axs, yticks = [i*0.2 for i in range(2+int(max_y/0.2))])

plt.savefig(img_path + epsilons_desc[epsilon] + "p12.svg", dpi = dpi_setting)
epsilons_desc[epsilon]
# Out:
# 'eps negative 3'

# %%
def compare(name1, name2, turnovers, cardinalities, col, local_path, epsilon_folder):


    for (i ,j) in product(range(len(cardinalities)), range(len(turnovers))):
        turnover = turnovers[j]
        card = cardinalities[i]
        with open(local_path + epsilon_folder+"/"+ cardinalities[0] + col +turnovers[0]+name1+".pkl", 'rb') as fp:
            new_adm_results = pickle.load(fp)
            weights_adm, oot_returns_adm, market_adm, wis_adm_1, bias_adm_1, soln_mods_adm = new_adm_results
            oot_returns_adm_test = (weights_adm.iloc[:-1]*rets).sum(axis = 1)

        with open(local_path + epsilon_folder+"/padm"+ cardinalities[0] + col +turnovers[0]+name2+".pkl", 'rb') as fp:
            new_adm_results2 = pickle.load(fp)
            weights_adm, oot_returns_adm, market_adm, wis_adm_2, bias_adm_2, soln_mods_adm, times = new_adm_results2
            oot_returns_adm_test2 = (weights_adm.iloc[:-1]*rets).sum(axis = 1)

        with open(local_path + "Cardinality Portfolios/"+card+"_"+turnover+"no_tlim.pkl",'rb') as fp:
            card_mvo_results = pickle.load(fp)
        with open(local_path + "Standard MVO Portfolios/"+turnover+"no_tlim.pkl",'rb') as fp:
            mvo_results = pickle.load(fp)
        with open(local_path + epsilons_desc[epsilon] + "/" + card + "_Vol_" +turnover + "no_tlim.pkl", 'rb') as fp:
            svm_results = pickle.load(fp)

        weights_card_mvo, oot_returns_card_mvo, market_card_mvo, wis_card_mvo, bias_card_mvo, soln_mods_card_mvo = card_mvo_results
        weights_mvo, oot_returns_mvo, market_mvo, wis_mvo, bias_mvo, soln_mods_mvo = mvo_results
        weights_svm, oot_returns_svm, market_svm, wis_svm, bias_svm, soln_mods_svm = svm_results

        oot_returns_card_mvo = (weights_card_mvo.iloc[:-1]*rets).sum(axis = 1)
        oot_returns_mvo = (weights_mvo.iloc[:-1]*rets).sum(axis = 1)
        oot_returns_svm = (weights_svm.iloc[:-1]*rets).sum(axis = 1)
        #
        # with open(local_path + "eps negative 2/padmCard01_Vol_1_25final.pkl", 'rb') as fp:
        #     new_adm_results3 = pickle.load(fp)
        #     weights_adm, oot_returns_svm, market_svm, wis_svm, bias_svm, soln_mods_svm, times = new_adm_results3
        #     oot_returns_adm_dict3 = (weights_adm.iloc[:-1]*rets).sum(axis = 1)

        turnover = turnovers[j]
        card = cardinalities[i]


        svm_wealth = wealth(oot_returns_svm)
        mvo_wealth = wealth(oot_returns_mvo)
        card_mvo_wealth = wealth(oot_returns_card_mvo)

        adm_wealth = wealth(oot_returns_adm_test)
        adm_wealth2 = wealth(oot_returns_adm_test2)
        # adm_wealth3 = wealth(oot_returns_adm_dict3)
        plt.figure()
        (svm_wealth/mvo_wealth).plot(label = 'Exact Solve - Vol', fontsize = 8)
        (adm_wealth/mvo_wealth).plot(label = name1, fontsize = 8, linewidth = 3)
        (adm_wealth2/mvo_wealth).plot(label = name2, fontsize = 8)
        # (adm_wealth3/mvo_wealth).plot(label = 'PADM - Fundamentals 3', fontsize = 8)
        (card_mvo_wealth/mvo_wealth).plot(label = 'Card-MVO', fontsize = 8)
        plt.legend()
        print("MVO ", RetStats(oot_returns_mvo, rf/100))
        print("Card MVO ", RetStats(oot_returns_card_mvo, rf/100))
        print("SVM ", RetStats(oot_returns_svm, rf/100))
        print(name1 + " ", RetStats(oot_returns_adm_test, rf/100))
        print(name2 + " ", RetStats(oot_returns_adm_test2, rf/100))
        # plt.figure()
        # plt.plot(wis_adm_1)
        # plt.figure()
        # plt.plot(bias_adm_1)
        # plt.figure()
        # plt.plot(wis_adm_2)
        # plt.figure()
        # plt.plot(bias_adm_2)

# %%
turnovers = ["1_25"]
cardinalities  = ["Card03"]
name1 = "test"
name2 = "balanced3"
col = "_Vol_"
epsilon_folder = "eps negative 3"

turnovers = ["0_75", "1", "1_25"]
for turnover in turnovers:
    print("Turnover ", turnover)
    compare(name1, name2, [turnover], cardinalities, col, local_path, epsilon_folder)
    print("_"*10)
# Out:
# Turnover  0_75
# MVO  ('11.9%', '11.5%', '1.03')
# Card MVO  ('12.7%', '10.9%', '1.16')
# SVM  ('13.9%', '12.3%', '1.12')
# test  ('13.7%', '10.9%', '1.26')
# balanced3  ('12.3%', '11.4%', '1.08')
# __________
# Turnover  1
# MVO  ('11.2%', '11.3%', '0.988')
# Card MVO  ('11.6%', '10.8%', '1.07')
# SVM  ('12.5%', '11.4%', '1.1')
# test  ('11.3%', '13.8%', '0.823')
# balanced3  ('11.6%', '10.9%', '1.06')
# __________
# Turnover  1_25
# MVO  ('10.9%', '11.2%', '0.976')
# Card MVO  ('10.7%', '10.7%', '1.0')
# SVM  ('11.2%', '12.5%', '0.898')
# test  ('12.0%', '10.8%', '1.11')
# balanced3  ('11.8%', '10.5%', '1.12')
# __________

# %%
turnovers = ["1_25"]
cardinalities  = ["Card01"]
name1 = "final_lightreg"
name2 = "final_reg"
col = "_INV3PRO6INV1_"
epsilon_folder = "eps negative 3"

compare(name1, name2, turnovers, cardinalities, col, local_path, epsilon_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1905], line 8
#       5 col = "_INV3PRO6INV1_"
#       6 epsilon_folder = "eps negative 3"
# ----> 8 compare(name1, name2, turnovers, cardinalities, col, local_path, epsilon_folder)
#
# Cell In [1892], line 5, in compare(name1, name2, turnovers, cardinalities, col, local_path, epsilon_folder)
#       3 turnover = turnovers[j]
#       4 card = cardinalities[i]
# ----> 5 with open(local_path + epsilon_folder+"/"+ cardinalities[0] + col +turnovers[0]+name1+".pkl", 'rb') as fp:
#       6     new_adm_results = pickle.load(fp)
#       7     weights_adm, oot_returns_adm, market_adm, wis_adm_1, bias_adm_1, soln_mods_adm = new_adm_results
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cache/Local Experiments/eps negative 3/Card01_INV3PRO6INV1_1_25final_lightreg.pkl'

# %%
def compare_files(triples, turnovers, cardinalities, col, local_path, epsilon_folder, label_dict = None):
    max_y = 0
    lw = 2

    if label_dict is None:
        label_dict = {}
        for triple in triples:
            label_dict[triple] = str(triple)

    fig, axs = plt.subplots(len(cardinalities), len(turnovers),
                        sharex=True, sharey = True, figsize=(6.5,8.5))

    #load in the appropriate files
    for (i ,j) in product(range(len(cardinalities)), range(len(turnovers))):
        turnover = turnovers[j]
        card = cardinalities[i]
        #load in benchmarks
        with open(local_path + "Cardinality Portfolios/"+card+"_"+turnover+"no_tlim.pkl",'rb') as fp:
            card_mvo_results = pickle.load(fp)
        with open(local_path + "Standard MVO Portfolios/"+turnover+"no_tlim.pkl",'rb') as fp:
            mvo_results = pickle.load(fp)

        weights_card_mvo  = card_mvo_results[0]
        weights_mvo =  mvo_results[0]

        oot_returns_mvo = (weights_mvo.iloc[:-1]*rets).sum(axis = 1)
        oot_returns_card_mvo = (weights_card_mvo.iloc[:-1]*rets).sum(axis = 1)

        mvo_wealth = wealth(oot_returns_mvo)
        card_mvo_wealth = wealth(oot_returns_card_mvo)

        (card_mvo_wealth/mvo_wealth).plot(label = 'Card-MVO', fontsize = 8, ax=axs[i, j], linewidth = lw)

        for triple in triples:
            prefix, col, name = triple
            with open(local_path + epsilon_folder+"/"+prefix+ card + col +turnover+name+".pkl", 'rb') as fp:
                results = pickle.load(fp)
                #weights_adm, oot_returns_adm, market_adm, wis_adm_1, bias_adm_1, soln_mods_adm = new_adm_results
            weights = results[0]
            oot_returns = (weights.iloc[:-1]*rets).sum(axis = 1)
            wealth_pair = wealth(oot_returns)
            (wealth_pair/mvo_wealth).plot(label = label_dict[triple], fontsize = 8, ax=axs[i, j], linewidth = lw)

            max_ = max(np.max((card_mvo_wealth/mvo_wealth)), np.max((wealth_pair/mvo_wealth)))
            if max_ > max_y:
                max_y = max_

        card_string = card_strings[i]
        turnover_string = turnover_strings[j]
        axs[i, j].set_title(card_string + ", " + turnover_string, fontsize = 8)

    for ax in axs:
        for sub_ax in ax:
            sub_ax.yaxis.set_tick_params(which='minor', bottom=False)
            sub_ax.set_yticks([min_y+i*0.2 for i in range(2+int((max_y - min_y)/0.2))])
            sub_ax.grid()
            sub_ax.set_xlabel("Trade Date",fontsize = 8)
    # fig.supxlabel('Trade Date',fontsize = 8)
    fig.supylabel("Cumulative Relative Wealth",fontsize = 8)
    #plt.tight_layout()
    fig.subplots_adjust(wspace = 0.05, hspace=0.4)
    #plt.setp(axs, yticks = [i*0.2 for i in range(2+int(max_y/0.2))])

# %%
turnovers = ["0_75", "1_25"]
cardinalities  = ["Card01", "Card03"]
name1 = "test"
name2 = "balanced3"
col = "_Vol_"
epsilon_folder = "eps negative 3"

triples = [('', "_Vol_", "test"), ('', "_Vol_", "no_tlim"), ('padm', "_Vol_", "balanced")]
compare_files(triples, turnovers, cardinalities, col, local_path, epsilon_folder, label_dict = None)

#RetStats(oot_returns_adm_test, rf/100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1910], line 9
#       6 epsilon_folder = "eps negative 3"
#       8 triples = [('', "_Vol_", "test"), ('', "_Vol_", "tlim"), ('padm', "_Vol_", "balanced")]
# ----> 9 compare_files(triples, turnovers, cardinalities, col, local_path, epsilon_folder, label_dict = None)
#
# Cell In [1908], line 36, in compare_files(triples, turnovers, cardinalities, col, local_path, epsilon_folder, label_dict)
#      34 for triple in triples:
#      35     prefix, col, name = triple
# ---> 36     with open(local_path + epsilon_folder+"/"+prefix+ card + col +turnover+name+".pkl", 'rb') as fp:
#      37         results = pickle.load(fp)
#      38         #weights_adm, oot_returns_adm, market_adm, wis_adm_1, bias_adm_1, soln_mods_adm = new_adm_results
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cache/Local Experiments/eps negative 3/Card01_Vol_0_75tlim.pkl'

# %%
#checking turnovers
print(weights_svm.diff().abs().sum().sum())
print(weights_adm_fundamentals.diff().abs().sum().sum())
print(weights_mvo.diff().abs().sum().sum())
# Out:
# 49.95771022806299
# 50.41668997889401
# 50.415421097750375

# %% [markdown]
# # Making Latex Tables

# %%
def RetStats(returns, rf=None, geomean=True):
    """Assumes returns is a pandas Series"""
    if rf is None:
        returns_rf = returns
    else:
        returns_rf = returns - rf
    P = 12
    P05 = P ** 0.5

    if geomean:
        mean = gmean(1 + returns_rf) - 1
    else:
        mean = returns_rf.mean()
    return "{:.1%}".format(P * mean), "{:.1%}".format(P05 * returns_rf[returns_rf < 0].std()), "{0:.3}".format(P * mean / (P05 * returns_rf[returns_rf < 0].std()))

# %%
def highlight_max(data, color='grey'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    #remove % and cast to float
    data = data.replace('%','', regex=True).astype(float)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        if data.columns[0] == "$\sigma$":
            is_max = data == data.min().min()
        else:
            is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
df_cols = []

for i in range(len(cardinalities)):
    df_rows = []

    for j in range(len(turnovers)):
        turnover = turnovers[j]
        card = cardinalities[i]
        card_string = card_strings[i]
        turnover_string = turnover_strings[j]
        oot_returns_svm = oot_returns_svm_dict[(card, turnover)]
        oot_returns_mvo = oot_returns_mvo_dict[(card, turnover)]
        oot_returns_card_mvo = oot_returns_card_mvo_dict[(card, turnover)]
        oot_returns_fund_adm = oot_returns_adm_fundamentals_dict[(card, turnover)]
        oot_returns_vol_adm = oot_returns_adm_vol_dict[(card, turnover)]

        row_tuples = [(turnover_string, "Card MVO"), (turnover_string, "MVO"), (turnover_string, "Exact Solve - Vol"), (turnover_string, "PADM - Fundamentals")]
        row_index = pd.MultiIndex.from_tuples(row_tuples)

        col_tuples =[(card_string, "$\mu$"), (card_string,"$\sigma$"), (card_string,"S.R")]
        col_index = pd.MultiIndex.from_tuples(col_tuples)

        out = pd.DataFrame([RetStats(oot_returns_card_mvo, rf/100), RetStats(oot_returns_mvo, rf/100), RetStats(oot_returns_svm, rf/100), RetStats(oot_returns_fund_adm, rf/100)],
                           index = row_index, columns = col_index)

        df_rows.append(out)

    column = pd.concat(df_rows)
    df_cols.append(column)

# %%
pd.concat(df_cols, axis = 1).to_csv(img_path+ epsilons_desc[epsilon]+".csv")

# %%
print(pd.concat(df_cols, axis = 1))
# Out:
#                                    $K = \lfloor 0.1N \rfloor$                  \
#                                                         $\mu$ $\sigma$    S.R
# $C_0 = 0.75/6$ Card MVO                                 12.3%    12.4%  0.996
#                MVO                                      11.9%    12.4%  0.966
#                Exact Solve - Vol                        12.0%    13.1%  0.914
#                PADM - Fundamentals                      11.7%    13.4%  0.879
# $C_0 = 1.00/6$ Card MVO                                 12.3%    12.8%  0.961
#                MVO                                      11.2%    12.2%  0.916
#                Exact Solve - Vol                        11.5%    13.3%  0.862
#                PADM - Fundamentals                      11.9%    13.0%  0.915
# $C_0 = 1.25/6$ Card MVO                                 10.9%    12.0%  0.914
#                MVO                                      10.9%    12.1%  0.905
#                Exact Solve - Vol                        12.5%    12.7%  0.978
#                PADM - Fundamentals                      11.0%    11.9%  0.919
#
#                                    $K = \lfloor0.3N\rfloor$                  \
#                                                       $\mu$ $\sigma$    S.R
# $C_0 = 0.75/6$ Card MVO                               12.7%    12.5%   1.01
#                MVO                                    11.9%    12.4%  0.966
#                Exact Solve - Vol                      13.9%    14.7%  0.944
#                PADM - Fundamentals                    12.6%    12.8%  0.986
# $C_0 = 1.00/6$ Card MVO                               11.6%    12.4%  0.929
#                MVO                                    11.2%    12.2%  0.916
#                Exact Solve - Vol                      12.5%    13.4%  0.933
#                PADM - Fundamentals                    11.7%    12.2%   0.96
# $C_0 = 1.25/6$ Card MVO                               10.7%    12.1%  0.888
#                MVO                                    10.9%    12.1%  0.905
#                Exact Solve - Vol                      11.2%    14.7%  0.763
#                PADM - Fundamentals                    12.1%    12.1%   1.01
#
#                                    $K = \lfloor0.5N \rfloor$                  \
#                                                        $\mu$ $\sigma$    S.R
# $C_0 = 0.75/6$ Card MVO                                12.5%    12.6%  0.998
#                MVO                                     11.9%    12.4%  0.966
#                Exact Solve - Vol                       13.6%    15.5%  0.876
#                PADM - Fundamentals                     13.2%    12.5%   1.06
# $C_0 = 1.00/6$ Card MVO                                11.6%    12.7%  0.915
#                MVO                                     11.2%    12.2%  0.916
#                Exact Solve - Vol                       13.5%    15.3%  0.886
#                PADM - Fundamentals                     11.1%    12.6%  0.877
# $C_0 = 1.25/6$ Card MVO                                11.3%    12.4%  0.918
#                MVO                                     10.9%    12.1%  0.905
#                Exact Solve - Vol                       13.2%    15.9%  0.828
#                PADM - Fundamentals                     11.1%    12.2%  0.914
#
#                                    $K = \lfloor0.7N \rfloor$                  \
#                                                        $\mu$ $\sigma$    S.R
# $C_0 = 0.75/6$ Card MVO                                12.7%    12.5%   1.01
#                MVO                                     11.9%    12.4%  0.966
#                Exact Solve - Vol                       14.3%    15.2%  0.939
#                PADM - Fundamentals                     13.2%    12.2%   1.08
# $C_0 = 1.00/6$ Card MVO                                11.7%    12.9%    0.9
#                MVO                                     11.2%    12.2%  0.916
#                Exact Solve - Vol                       13.4%    14.5%  0.922
#                PADM - Fundamentals                     11.5%    12.6%  0.919
# $C_0 = 1.25/6$ Card MVO                                10.5%    12.2%  0.862
#                MVO                                     10.9%    12.1%  0.905
#                Exact Solve - Vol                       13.3%    14.8%    0.9
#                PADM - Fundamentals                     11.0%    12.1%  0.909
#
#                                    $K = \lfloor0.9N \rfloor$
#                                                        $\mu$ $\sigma$    S.R
# $C_0 = 0.75/6$ Card MVO                                12.5%    12.4%   1.01
#                MVO                                     11.9%    12.4%  0.966
#                Exact Solve - Vol                       13.7%    13.6%   1.01
#                PADM - Fundamentals                     12.2%    12.8%  0.951
# $C_0 = 1.00/6$ Card MVO                                11.6%    12.4%  0.929
#                MVO                                     11.2%    12.2%  0.916
#                Exact Solve - Vol                       13.3%    13.8%  0.965
#                PADM - Fundamentals                     11.3%    12.2%  0.922
# $C_0 = 1.25/6$ Card MVO                                10.6%    12.3%  0.855
#                MVO                                     10.9%    12.1%  0.905
#                Exact Solve - Vol                       12.4%    13.1%  0.945
#                PADM - Fundamentals                     11.1%    12.0%  0.925

# %%
out.style

# %%
for (turnover, card) in product(turnovers, cardinalities):

    with open(local_path + "Cardinality Portfolios/"+card+"_"+turnover+"no_tlim.pkl",'rb') as fp:
        card_mvo_results = pickle.load(fp)
    with open(local_path + "Standard MVO Portfolios/"+turnover+"no_tlim.pkl",'rb') as fp:
        mvo_results = pickle.load(fp)
    # with open(pth + "svm_oot_results_turnover0_75by6.pkl", 'rb') as fp:
    #   svm_results = pickle.load(fp)
    with open(local_path + epsilons_desc[epsilon] + "/" + card + "_Vol_" +turnover + "no_tlim.pkl", 'rb') as fp:
        svm_results = pickle.load(fp)
    with open(local_path + epsilons_desc[epsilon] + "/" + "padm" +card+ cols +turnover + name + ".pkl", 'rb') as fp:
        adm_results = pickle.load(fp)

#     with open(local_path + epsilons_desc[epsilon] + "/" + "padm" +card+ "_VolINV3_" +turnover + "no_neg.pkl", 'rb') as fp:
#         adm_results2 = pickle.load(fp)
    weights_card_mvo, oot_returns_card_mvo, market_card_mvo, wis_card_mvo, bias_card_mvo, soln_mods_card_mvo = card_mvo_results
    weights_mvo, oot_returns_mvo, market_mvo, wis_mvo, bias_mvo, soln_mods_mvo = mvo_results
    weights_svm, oot_returns_svm, market_svm, wis_svm, bias_svm, soln_mods_svm = svm_results
    weights_adm, oot_returns_adm, market_adm, wis_adm, bias_adm, soln_mods_adm, times = adm_results

# %%
U = np.max(np.abs(np.max(wis_adm, axis = 1)) + np.abs(bias_adm))

bigM = 0
def padm_data_treatment(Y):
    # Y['Momentum'] = wrds_tics.Momentum
    #restrict the wharton research data to the columns of interest
    Y_ = (Y.rank(axis = 0)/(len(Y))+1)
    Y_ =  (Y_ - Y_.mean(axis=0))/(Y_.std(axis=0)) #scale the features
    return Y_

for prd in rets.index.to_list()[:T]:
    
    forecasts = pd.read_pickle('cache/Forecasts.pkl')
    
    cov_, mean_ = forecasts[prd]
    N = len(mean_)
    cov = cov_[:N,:N]
    mean = mean_[:N,:]
    tics = list(rets.columns[:N])
    
    #get the wharton research data for the valid tickers for the month
    wrds_tics = wrds_svm[wrds_svm.index.get_level_values('tic').isin(tics)].xs(prd, level="MonthStart")
    cols =  ['INV3', 'PRO6', 'INV1'] 
    Y = wrds_tics.loc[:,cols] # Y matrix in formulation
    
    Y = padm_data_treatment(Y)
    
    largest_norm = Y.abs().sum(axis = 1).max()
    new_bigM = largest_norm*U + U
    if new_bigM > bigM:
        bigM = new_bigM

# %%
bigM

# %%
100/largest_norm

# %%
U
